# %%
#https://www.kaggle.com/code/prashant111/a-guide-on-xgboost-hyperparameters-tuning 
#https://www.kaggle.com/code/donkeys/exploring-hyperopt-parameter-tuning
#https://hyperopt.github.io/hyperopt/getting-started/search_spaces/
#some more cool stuff for this specific dataset https://www.kaggle.com/code/rifqihaikal/diamonds-lr-xgboost-eda

import numpy as np
import pandas as pd
import xgboost as xgb
from matplotlib import pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_percentage_error
# import packages for hyperparameters tuning
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

# %%
xgb.set_config(verbosity=0)
config = xgb.get_config()
config
# Out:
# {'use_rmm': False, 'verbosity': 0}

# %%
df = pd.read_csv("diamonds.csv", sep=",", header=0)

X, y = df.drop('price', axis=1), df[['price']] #drop price from X, assign price to y

cats = X.select_dtypes(exclude=np.number).columns.tolist()
for col in cats:
   X[col] = X[col].astype('category')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.33)

dtrain_reg = xgb.DMatrix(X_train, y_train, enable_categorical=True) #train dataset
dtest_reg = xgb.DMatrix(X_test, y_test, enable_categorical=True) #test dataset
evals = [(dtrain_reg, "train"), (dtest_reg, "validation")]

# %%
def simulate_quniform(low, high, q, size=100):
    # Simulate the behavior of hp.quniform
    samples = np.random.uniform(low, high+q, size)
    rounded_samples = np.round(samples / q) * q
    return rounded_samples

def simulate_uniform(low, high, size=10):
    # Simulate the behavior of hp.uniform
    samples = np.random.uniform(low, high, size)
    return samples



simulated_q_values = simulate_quniform(3, 18, 1)
print(simulated_q_values)

print("------------------")
simulated_u_values = simulate_uniform(0.1, 1)
print(simulated_u_values)
# Out:
# [12.  7. 12. 15.  8. 12.  5.  5. 14.  4. 10. 14. 19. 15.  4. 13. 11.  9.
#  11. 18.  5. 16.  5. 17.  7. 11. 15. 15. 16. 19.  5. 14.  4.  8.  8.  9.
#  16. 16. 18. 13. 11.  9.  5.  4.  3. 12. 12. 17.  7. 13. 10. 17. 13. 16.
#  10. 10. 12. 14.  5. 11.  8.  7.  5. 12.  4. 16.  6.  9.  6. 16.  5. 12.
#   9.  4.  4.  8.  4. 13. 11.  8. 11.  9.  5. 17. 15. 15.  9. 13.  8. 15.
#   4.  3. 15. 19. 14.  8. 18.  3. 19. 16.]
# ------------------
# [0.1780184  0.32409246 0.17345999 0.35949232 0.73168595 0.57297747
#  0.27417437 0.74726213 0.11491309 0.72179357]

# %%
#https://www.databricks.com/blog/2021/04/15/how-not-to-tune-your-model-with-hyperopt.html
#I used chatGPT and then used the functions above to validate

# hp.uniform:

# hp.uniform(label, low, high) samples a floating-point value uniformly between low and high.
# It is used for continuous hyperparameters.
# For example, hp.uniform('x', 0, 1) will generate a random floating-point number between 0 and 1.
# hp.quniform:

# hp.quniform(label, low, high, q) samples a floating-point value uniformly between low and high, and then rounds the result to the nearest 
# multiple of q.
# It is often used for discrete hyperparameters, especially when you want to sample integers.
# The rounding behavior means it can effectively generate integer values if q is set to 1.
# For example, hp.quniform('x', 0, 10, 1) will generate a value like 3.0, 4.0, etc., effectively giving integers between 0 and 10.



space={'max_depth': hp.quniform("max_depth", 1, 25, 1), 
        'colsample_bytree': hp.uniform('colsample_bytree', 0.0,1), #It is the fraction of features that can be selected during any given boosting rounds.
        'min_child_weight': hp.quniform('min_child_weight', 0, 10, 1), 
        'reg_alpha': hp.quniform('reg_alpha', 1,10,1),
        'reg_lambda': hp.quniform('reg_lambda', 1,10,1),
        'gamma': hp.quniform ('gamma', 0,10,1),
        'eta': hp.uniform('eta', 0.1,1), #learning_rate,
        'n_estimators': hp.quniform('n_estimators', 100, 6000, 1),
        'seed': 42
    }

# %%
def objective(space):
    params = {"objective": "reg:squarederror", 
                "tree_method": "hist",
                "max_depth": int(space['max_depth']), #range 0, inf
                "colsample_bytree": space['colsample_bytree'], #range 0,1
                "min_child_weight": int(space['min_child_weight']), #range 0, inf
                "reg_alpha": int(space['reg_alpha']), #range 0, inf
                "reg_lambda": int(space['reg_lambda']), #range 0, inf
                "gamma": int(space['gamma']), #range 0, inf
                "eta": space['eta'], #range 0,1
                #"booster": "dart" #check this for dart https://xgboost.readthedocs.io/en/stable/parameter.html#additional-parameters-for-dart-booster-booster-dart
                } 
    n = int(space['n_estimators'])
  
    model = xgb.train(
        params=params,
        dtrain=dtrain_reg,
        num_boost_round=n,
        evals=evals,
        verbose_eval=100, # Every ten rounds
        early_stopping_rounds=50
    )

    preds = model.predict(dtest_reg)
    rmse = mean_squared_error(y_test, preds, squared=False)
    print(f"RMSE of the base model: {rmse:.3f}") #the lower the value the better

    mape = mean_absolute_percentage_error(y_test, preds)
    print(f"MAPE of the base model: {mape:.3f}") #the lower the value the better

    #predictions = [round(value) for value in preds]
    #accuracy = accuracy_score(y_test, predictions)
    #print("Accuracy: %.2f%%" % (accuracy * 100.0))

    
    accuracy = accuracy_score(y_test, preds>0.5)
    print ("SCORE:", accuracy)
    print({'loss': -accuracy, 'status': STATUS_OK })
    return {'loss': -accuracy, 'status': STATUS_OK }

# %%
trials = Trials()

best_hyperparams = fmin(fn = objective,
                        space = space,
                        algo = tpe.suggest,
                        max_evals = 50, #will be hundreds, maybe thousands, and determine sampling
                        trials = trials)
# Out:
# [0]	train-rmse:831.42557	validation-rmse:832.62637
# [51]	train-rmse:16.29540	validation-rmse:686.34204
# RMSE of the base model: 686.347
# MAPE of the base model: 0.087
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:4311.19847	validation-rmse:4230.90932
# [90]	train-rmse:185.95941	validation-rmse:559.10283
# RMSE of the base model: 559.066
# MAPE of the base model: 0.069
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1523.29637	validation-rmse:1483.10207
# [100]	train-rmse:1030.35138	validation-rmse:1033.12615
# [200]	train-rmse:1026.67924	validation-rmse:1031.96749
# [300]	train-rmse:1024.26072	validation-rmse:1030.46016
# [400]	train-rmse:1022.81385	validation-rmse:1029.57492
# [500]	train-rmse:1021.24002	validation-rmse:1028.72680
# [600]	train-rmse:1019.90912	validation-rmse:1027.68748
# [700]	train-rmse:1018.71950	validation-rmse:1026.94161
# [800]	train-rmse:1017.69079	validation-rmse:1026.06307
# [900]	train-rmse:1016.98966	validation-rmse:1025.63379
# [1000]	train-rmse:1016.10150	validation-rmse:1024.70380
# [1100]	train-rmse:1015.74487	validation-rmse:1024.49826
# [1200]	train-rmse:1015.04332	validation-rmse:1023.88429
# [1300]	train-rmse:1014.58504	validation-rmse:1023.48226
# [1400]	train-rmse:1014.00037	validation-rmse:1022.87591
# [1500]	train-rmse:1013.50461	validation-rmse:1022.40305
# [1600]	train-rmse:1012.81811	validation-rmse:1021.79245
# [1700]	train-rmse:1012.45518	validation-rmse:1021.54636
# [1748]	train-rmse:1012.10905	validation-rmse:1021.18797
# RMSE of the base model: 1021.188
# MAPE of the base model: 0.354
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1515.14563	validation-rmse:1475.33007
# [100]	train-rmse:1029.89562	validation-rmse:1033.53539
# [200]	train-rmse:1026.36010	validation-rmse:1032.23142
# [300]	train-rmse:1023.94907	validation-rmse:1030.66684
# [400]	train-rmse:1022.51766	validation-rmse:1029.86065
# [500]	train-rmse:1020.95112	validation-rmse:1028.91656
# [600]	train-rmse:1019.63824	validation-rmse:1027.88718
# [700]	train-rmse:1018.45536	validation-rmse:1027.10866
# [800]	train-rmse:1017.43158	validation-rmse:1026.24340
# [900]	train-rmse:1016.73853	validation-rmse:1025.81621
# [1000]	train-rmse:1015.85775	validation-rmse:1024.89049
# [1083]	train-rmse:1015.56993	validation-rmse:1024.73578
# RMSE of the base model: 1024.737
# MAPE of the base model: 0.356
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:4495.46747	validation-rmse:4403.57239
# [100]	train-rmse:1033.24375	validation-rmse:1027.37680
# [200]	train-rmse:1019.21273	validation-rmse:1020.63429
# [300]	train-rmse:1017.48896	validation-rmse:1020.61987
# [343]	train-rmse:1017.07753	validation-rmse:1020.78142
# RMSE of the base model: 1020.781
# MAPE of the base model: 0.352
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:2177.21038	validation-rmse:2100.71045
# [100]	train-rmse:620.11865	validation-rmse:629.49432
# [200]	train-rmse:591.30517	validation-rmse:611.52212
# [300]	train-rmse:577.20875	validation-rmse:605.12636
# [400]	train-rmse:566.08698	validation-rmse:600.25523
# [500]	train-rmse:558.64753	validation-rmse:598.79417
# [600]	train-rmse:552.64096	validation-rmse:598.02762
# [614]	train-rmse:552.02149	validation-rmse:598.01005
# RMSE of the base model: 598.003
# MAPE of the base model: 0.126
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:3046.44971	validation-rmse:2984.20464
# [100]	train-rmse:366.19978	validation-rmse:700.41596
# [148]	train-rmse:319.77570	validation-rmse:710.62301
# RMSE of the base model: 710.688
# MAPE of the base model: 0.120
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:3590.55041	validation-rmse:3522.63675
# [100]	train-rmse:338.94227	validation-rmse:723.54586
# [149]	train-rmse:291.45369	validation-rmse:730.55069
# RMSE of the base model: 730.551
# MAPE of the base model: 0.115
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1795.01177	validation-rmse:1747.88273
# [100]	train-rmse:486.61892	validation-rmse:583.04438
# [200]	train-rmse:434.51001	validation-rmse:576.30182
# [269]	train-rmse:410.78230	validation-rmse:576.91468
# RMSE of the base model: 576.915
# MAPE of the base model: 0.081
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:4831.01952	validation-rmse:4743.20651
# [88]	train-rmse:16.61623	validation-rmse:557.42255
# RMSE of the base model: 557.428
# MAPE of the base model: 0.064
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1216.67413	validation-rmse:1179.32248
# [58]	train-rmse:69.02833	validation-rmse:638.70330
# RMSE of the base model: 638.652
# MAPE of the base model: 0.081
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1578.51970	validation-rmse:1545.74117
# [93]	train-rmse:326.52080	validation-rmse:730.80479
# RMSE of the base model: 730.910
# MAPE of the base model: 0.125
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:3187.24797	validation-rmse:3120.10257
# [72]	train-rmse:185.37926	validation-rmse:584.59813
# RMSE of the base model: 584.598
# MAPE of the base model: 0.075
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1129.57056	validation-rmse:1096.18429
# [58]	train-rmse:168.82439	validation-rmse:643.26459
# RMSE of the base model: 643.265
# MAPE of the base model: 0.090
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:3085.91694	validation-rmse:3007.92060
# [100]	train-rmse:1027.86899	validation-rmse:1021.94983
# [152]	train-rmse:1024.31278	validation-rmse:1022.24981
# RMSE of the base model: 1022.241
# MAPE of the base model: 0.352
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1127.62744	validation-rmse:1099.65197
# [56]	train-rmse:49.71325	validation-rmse:639.74660
# RMSE of the base model: 639.743
# MAPE of the base model: 0.082
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:3647.55113	validation-rmse:3574.14692
# [100]	train-rmse:491.05479	validation-rmse:558.00844
# [200]	train-rmse:441.11193	validation-rmse:546.68441
# [247]	train-rmse:427.78700	validation-rmse:547.68708
# RMSE of the base model: 547.700
# MAPE of the base model: 0.082
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:3587.99512	validation-rmse:3508.52097
# [100]	train-rmse:568.35698	validation-rmse:596.71824
# [200]	train-rmse:532.02635	validation-rmse:578.51913
# [300]	train-rmse:502.54314	validation-rmse:562.75941
# [400]	train-rmse:480.90155	validation-rmse:551.97150
# [500]	train-rmse:466.78658	validation-rmse:549.91160
# [600]	train-rmse:456.63399	validation-rmse:548.85700
# [671]	train-rmse:449.43421	validation-rmse:548.64387
# RMSE of the base model: 548.638
# MAPE of the base model: 0.081
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:4226.14793	validation-rmse:4144.82021
# [100]	train-rmse:418.42561	validation-rmse:536.52084
# [129]	train-rmse:399.90804	validation-rmse:536.27395
# RMSE of the base model: 536.274
# MAPE of the base model: 0.072
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:2923.40629	validation-rmse:2864.61104
# [100]	train-rmse:305.51675	validation-rmse:564.82195
# [103]	train-rmse:301.08739	validation-rmse:565.57741
# RMSE of the base model: 565.577
# MAPE of the base model: 0.073
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:2170.70053	validation-rmse:2128.79303
# [56]	train-rmse:149.93389	validation-rmse:620.54437
# RMSE of the base model: 620.544
# MAPE of the base model: 0.075
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:2301.30135	validation-rmse:2250.23421
# [65]	train-rmse:249.71543	validation-rmse:580.62305
# RMSE of the base model: 580.778
# MAPE of the base model: 0.075
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:2278.33953	validation-rmse:2234.61217
# [60]	train-rmse:246.48938	validation-rmse:589.72721
# RMSE of the base model: 589.727
# MAPE of the base model: 0.074
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:2124.33016	validation-rmse:2082.01675
# [54]	train-rmse:136.40574	validation-rmse:616.03233
# RMSE of the base model: 616.032
# MAPE of the base model: 0.074
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:869.84363	validation-rmse:856.66280
# [52]	train-rmse:29.22166	validation-rmse:667.68507
# RMSE of the base model: 667.685
# MAPE of the base model: 0.087
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:770.10848	validation-rmse:779.05285
# [51]	train-rmse:16.13361	validation-rmse:681.81696
# RMSE of the base model: 681.817
# MAPE of the base model: 0.086
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1761.97937	validation-rmse:1710.92014
# [95]	train-rmse:1027.14730	validation-rmse:1032.97588
# RMSE of the base model: 1032.976
# MAPE of the base model: 0.358
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:846.96450	validation-rmse:836.83598
# [51]	train-rmse:19.41995	validation-rmse:670.26633
# RMSE of the base model: 670.260
# MAPE of the base model: 0.088
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:780.82491	validation-rmse:787.60547
# [51]	train-rmse:16.07502	validation-rmse:677.72346
# RMSE of the base model: 677.723
# MAPE of the base model: 0.085
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1505.32274	validation-rmse:1497.56275
# [56]	train-rmse:55.69894	validation-rmse:752.84144
# RMSE of the base model: 752.841
# MAPE of the base model: 0.111
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:900.17043	validation-rmse:887.34404
# [55]	train-rmse:87.61177	validation-rmse:707.34254
# RMSE of the base model: 707.343
# MAPE of the base model: 0.096
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1885.56797	validation-rmse:1852.22916
# [56]	train-rmse:16.17559	validation-rmse:619.47283
# RMSE of the base model: 619.473
# MAPE of the base model: 0.078
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1383.16794	validation-rmse:1381.93785
# [55]	train-rmse:77.83376	validation-rmse:755.44969
# RMSE of the base model: 755.847
# MAPE of the base model: 0.108
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:948.68730	validation-rmse:933.46166
# [56]	train-rmse:72.41481	validation-rmse:689.35094
# RMSE of the base model: 689.387
# MAPE of the base model: 0.096
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1729.64683	validation-rmse:1698.32817
# [54]	train-rmse:17.14152	validation-rmse:657.80836
# RMSE of the base model: 657.807
# MAPE of the base model: 0.085
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:2587.15894	validation-rmse:2534.62600
# [61]	train-rmse:147.12672	validation-rmse:594.38855
# RMSE of the base model: 594.429
# MAPE of the base model: 0.077
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:4410.82094	validation-rmse:4310.06729
# [100]	train-rmse:1072.53934	validation-rmse:1054.23773
# [200]	train-rmse:1058.58042	validation-rmse:1041.05380
# [300]	train-rmse:1051.76280	validation-rmse:1034.00076
# [400]	train-rmse:1047.33414	validation-rmse:1029.36737
# [500]	train-rmse:1044.04864	validation-rmse:1026.06038
# [600]	train-rmse:1041.49709	validation-rmse:1023.76389
# [700]	train-rmse:1039.41249	validation-rmse:1021.90786
# [800]	train-rmse:1037.62484	validation-rmse:1020.35075
# [900]	train-rmse:1036.10569	validation-rmse:1019.11588
# [1000]	train-rmse:1034.75920	validation-rmse:1017.84078
# [1100]	train-rmse:1033.57630	validation-rmse:1016.72001
# [1200]	train-rmse:1032.51687	validation-rmse:1015.83603
# [1300]	train-rmse:1031.55590	validation-rmse:1014.98742
# [1400]	train-rmse:1030.67433	validation-rmse:1014.20534
# [1500]	train-rmse:1029.86504	validation-rmse:1013.68141
# [1600]	train-rmse:1029.11451	validation-rmse:1013.04149
# [1631]	train-rmse:1028.89380	validation-rmse:1012.90790
# RMSE of the base model: 1012.908
# MAPE of the base model: 0.340
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:4935.03781	validation-rmse:4839.51245
# [100]	train-rmse:1071.75310	validation-rmse:1059.54020
# [200]	train-rmse:1024.94598	validation-rmse:1021.44667
# [300]	train-rmse:1019.10834	validation-rmse:1018.73956
# [344]	train-rmse:1018.15158	validation-rmse:1018.80292
# RMSE of the base model: 1018.783
# MAPE of the base model: 0.341
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:2544.71080	validation-rmse:2488.46005
# [71]	train-rmse:315.33465	validation-rmse:575.38820
# RMSE of the base model: 575.669
# MAPE of the base model: 0.076
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:4629.53686	validation-rmse:4543.01775
# [91]	train-rmse:182.25264	validation-rmse:548.15737
# RMSE of the base model: 548.078
# MAPE of the base model: 0.064
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1941.92630	validation-rmse:1895.49946
# [55]	train-rmse:91.12482	validation-rmse:595.29529
# RMSE of the base model: 595.295
# MAPE of the base model: 0.074
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:3324.42631	validation-rmse:3261.81783
# [67]	train-rmse:279.42379	validation-rmse:555.31867
# RMSE of the base model: 555.319
# MAPE of the base model: 0.070
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:3894.26059	validation-rmse:3821.51922
# [100]	train-rmse:361.94028	validation-rmse:716.89440
# [148]	train-rmse:314.07012	validation-rmse:723.02059
# RMSE of the base model: 723.002
# MAPE of the base model: 0.114
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1369.13136	validation-rmse:1367.36658
# [52]	train-rmse:127.78177	validation-rmse:689.22912
# RMSE of the base model: 689.198
# MAPE of the base model: 0.092
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1662.02457	validation-rmse:1620.00127
# [55]	train-rmse:107.73942	validation-rmse:629.24265
# RMSE of the base model: 629.243
# MAPE of the base model: 0.081
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1351.89932	validation-rmse:1328.94198
# [56]	train-rmse:57.19293	validation-rmse:657.10614
# RMSE of the base model: 657.106
# MAPE of the base model: 0.091
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1083.83976	validation-rmse:1052.70896
# [60]	train-rmse:19.01221	validation-rmse:645.86765
# RMSE of the base model: 645.868
# MAPE of the base model: 0.084
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1581.76398	validation-rmse:1540.99561
# [56]	train-rmse:21.53575	validation-rmse:614.81828
# RMSE of the base model: 614.818
# MAPE of the base model: 0.076
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:2115.45974	validation-rmse:2050.76773
# [95]	train-rmse:1025.96923	validation-rmse:1029.99117
# RMSE of the base model: 1029.991
# MAPE of the base model: 0.357
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# [0]	train-rmse:1724.97183	validation-rmse:1669.55482
# [100]	train-rmse:1028.05710	validation-rmse:1032.02034
# [200]	train-rmse:1024.77910	validation-rmse:1030.82199
# [300]	train-rmse:1022.67560	validation-rmse:1029.46041
# [400]	train-rmse:1021.35367	validation-rmse:1028.56727
# [500]	train-rmse:1019.91730	validation-rmse:1027.64284
# [600]	train-rmse:1018.73507	validation-rmse:1026.71038
# [700]	train-rmse:1017.67460	validation-rmse:1026.02296
# [800]	train-rmse:1016.72902	validation-rmse:1025.25939
# [900]	train-rmse:1016.08844	validation-rmse:1024.85103
# [1000]	train-rmse:1015.26622	validation-rmse:1024.03214
# [1100]	train-rmse:1014.93734	validation-rmse:1023.84125
# [1200]	train-rmse:1014.28392	validation-rmse:1023.26240
# [1300]	train-rmse:1013.86254	validation-rmse:1022.90288
# [1400]	train-rmse:1013.31856	validation-rmse:1022.37695
# [1500]	train-rmse:1012.86575	validation-rmse:1021.94344
# [1600]	train-rmse:1012.22344	validation-rmse:1021.39161
# [1700]	train-rmse:1011.88234	validation-rmse:1021.17203
# [1800]	train-rmse:1011.34152	validation-rmse:1020.57367
# [1900]	train-rmse:1010.83957	validation-rmse:1020.09298
# [2000]	train-rmse:1010.38084	validation-rmse:1019.59812
# [2100]	train-rmse:1010.04040	validation-rmse:1019.30934
# [2200]	train-rmse:1009.56454	validation-rmse:1018.73733
# [2226]	train-rmse:1009.46133	validation-rmse:1018.62308
# RMSE of the base model: 1018.623
# MAPE of the base model: 0.354
# SCORE:
# 0.0
# {'loss': -0.0, 'status': 'ok'}
# 100%|██████████████████████████████████████████████████████████████| 50/50 [02:01<00:00,  2.43s/trial, best loss: -0.0]

# %%
#just for funzies
for trial in trials.trials:
    print(trial['misc']['vals'])
# Out:
# {'colsample_bytree': [0.7000000000000001], 'eta': [0.2], 'gamma': [5.90107336873019], 'max_depth': [26.0], 'min_child_weight': [13.0], 'n_estimators': [5211.0], 'reg_alpha': [14.377958842857801], 'reg_lambda': [6.679091213160025]}
# {'colsample_bytree': [0.2], 'eta': [0.1], 'gamma': [0.22559990053647727], 'max_depth': [17.0], 'min_child_weight': [18.0], 'n_estimators': [5815.0], 'reg_alpha': [10.141340650400668], 'reg_lambda': [8.419197287292292]}
# {'colsample_bytree': [0.8], 'eta': [0.8], 'gamma': [2.4120929600679575], 'max_depth': [24.0], 'min_child_weight': [7.0], 'n_estimators': [3209.0], 'reg_alpha': [6.620833830082047], 'reg_lambda': [12.608307950074646]}
# {'colsample_bytree': [0.8], 'eta': [0.9], 'gamma': [10.188225076717414], 'max_depth': [25.0], 'min_child_weight': [0.0], 'n_estimators': [4983.0], 'reg_alpha': [3.7938810879097544], 'reg_lambda': [8.456740860146223]}
# {'colsample_bytree': [0.9], 'eta': [0.8], 'gamma': [19.413102582503846], 'max_depth': [20.0], 'min_child_weight': [20.0], 'n_estimators': [2827.0], 'reg_alpha': [4.35322344384288], 'reg_lambda': [3.777373622969583]}
# {'colsample_bytree': [0.7000000000000001], 'eta': [0.6000000000000001], 'gamma': [7.636512539685545], 'max_depth': [5.0], 'min_child_weight': [19.0], 'n_estimators': [5605.0], 'reg_alpha': [8.680453896994962], 'reg_lambda': [18.673568107715628]}
# {'colsample_bytree': [0.2], 'eta': [0.8], 'gamma': [19.953838673907427], 'max_depth': [13.0], 'min_child_weight': [6.0], 'n_estimators': [5434.0], 'reg_alpha': [8.98453667157297], 'reg_lambda': [7.577494413286404]}
# {'colsample_bytree': [0.4], 'eta': [0.2], 'gamma': [3.4160002626825836], 'max_depth': [29.0], 'min_child_weight': [1.0], 'n_estimators': [5633.0], 'reg_alpha': [17.066777868870876], 'reg_lambda': [18.673024937048318]}
# {'colsample_bytree': [0.6000000000000001], 'eta': [0.2], 'gamma': [8.79807247780495], 'max_depth': [9.0], 'min_child_weight': [0.0], 'n_estimators': [1883.0], 'reg_alpha': [16.97711378781011], 'reg_lambda': [17.487090444683627]}
# {'colsample_bytree': [0.6000000000000001], 'eta': [0.30000000000000004], 'gamma': [4.279015627178109], 'max_depth': [7.0], 'min_child_weight': [17.0], 'n_estimators': [2613.0], 'reg_alpha': [15.50326196282063], 'reg_lambda': [16.238263422340076]}
# {'colsample_bytree': [0.6000000000000001], 'eta': [0.30000000000000004], 'gamma': [13.997202472541147], 'max_depth': [9.0], 'min_child_weight': [8.0], 'n_estimators': [2032.0], 'reg_alpha': [2.9058627195059885], 'reg_lambda': [14.257344505170591]}
# {'colsample_bytree': [0.5], 'eta': [0.7000000000000001], 'gamma': [1.8366512980938787], 'max_depth': [7.0], 'min_child_weight': [18.0], 'n_estimators': [2815.0], 'reg_alpha': [10.677697153448536], 'reg_lambda': [2.2566971262270776]}
# {'colsample_bytree': [0.4], 'eta': [0.9], 'gamma': [19.20248185446092], 'max_depth': [24.0], 'min_child_weight': [17.0], 'n_estimators': [1368.0], 'reg_alpha': [2.3115958066535605], 'reg_lambda': [13.816682615129345]}
# {'colsample_bytree': [0.30000000000000004], 'eta': [0.6000000000000001], 'gamma': [11.329513868020982], 'max_depth': [5.0], 'min_child_weight': [18.0], 'n_estimators': [3776.0], 'reg_alpha': [2.8435752078482093], 'reg_lambda': [15.449641505593124]}
# {'colsample_bytree': [0.30000000000000004], 'eta': [0.4], 'gamma': [3.180516320916107], 'max_depth': [12.0], 'min_child_weight': [16.0], 'n_estimators': [5454.0], 'reg_alpha': [1.2611931042711628], 'reg_lambda': [3.2456471587335916]}
# {'colsample_bytree': [0.8], 'eta': [0.2], 'gamma': [18.657928776556474], 'max_depth': [25.0], 'min_child_weight': [20.0], 'n_estimators': [4199.0], 'reg_alpha': [2.872309891955677], 'reg_lambda': [4.939043787157317]}
# {'colsample_bytree': [0.1], 'eta': [0.9], 'gamma': [6.164711762311333], 'max_depth': [16.0], 'min_child_weight': [6.0], 'n_estimators': [4163.0], 'reg_alpha': [5.318315182580799], 'reg_lambda': [11.888583249479979]}
# {'colsample_bytree': [0.30000000000000004], 'eta': [0.5], 'gamma': [2.856702273114835], 'max_depth': [11.0], 'min_child_weight': [2.0], 'n_estimators': [1625.0], 'reg_alpha': [5.418315197336562], 'reg_lambda': [14.028905455934144]}
# {'colsample_bytree': [0.4], 'eta': [0.5], 'gamma': [6.864183348205721], 'max_depth': [30.0], 'min_child_weight': [12.0], 'n_estimators': [1236.0], 'reg_alpha': [13.57506804117562], 'reg_lambda': [10.46691246604418]}
# {'colsample_bytree': [0.5], 'eta': [0.2], 'gamma': [6.116101023213525], 'max_depth': [20.0], 'min_child_weight': [0.0], 'n_estimators': [1974.0], 'reg_alpha': [3.674335500926377], 'reg_lambda': [13.186950995520398]}
# {'colsample_bytree': [0.1], 'eta': [0.4], 'gamma': [15.151096057997773], 'max_depth': [13.0], 'min_child_weight': [13.0], 'n_estimators': [4609.0], 'reg_alpha': [12.468415748169507], 'reg_lambda': [6.759196438428158]}
# {'colsample_bytree': [1.0], 'eta': [0.5], 'gamma': [12.195242633571892], 'max_depth': [29.0], 'min_child_weight': [12.0], 'n_estimators': [1040.0], 'reg_alpha': [19.78309498383226], 'reg_lambda': [9.43230964586769]}
# {'colsample_bytree': [0.7000000000000001], 'eta': [0.1], 'gamma': [5.242251023509322], 'max_depth': [21.0], 'min_child_weight': [4.0], 'n_estimators': [2348.0], 'reg_alpha': [13.323842734471027], 'reg_lambda': [5.923155491035805]}
# {'colsample_bytree': [0.0], 'eta': [0.4], 'gamma': [16.68363799818682], 'max_depth': [2.0], 'min_child_weight': [13.0], 'n_estimators': [4822.0], 'reg_alpha': [12.110515587216188], 'reg_lambda': [1.2644753616007796]}
# {'colsample_bytree': [1.0], 'eta': [0.30000000000000004], 'gamma': [11.861386604567267], 'max_depth': [28.0], 'min_child_weight': [10.0], 'n_estimators': [3347.0], 'reg_alpha': [19.801719015219245], 'reg_lambda': [10.118102331270489]}
# {'colsample_bytree': [0.7000000000000001], 'eta': [0.1], 'gamma': [4.929875390838351], 'max_depth': [21.0], 'min_child_weight': [4.0], 'n_estimators': [2401.0], 'reg_alpha': [14.660706186597718], 'reg_lambda': [5.2157629601689575]}
# {'colsample_bytree': [0.0], 'eta': [0.4], 'gamma': [16.390633047761327], 'max_depth': [18.0], 'min_child_weight': [14.0], 'n_estimators': [4935.0], 'reg_alpha': [11.497265083108045], 'reg_lambda': [1.007747983188958]}
# {'colsample_bytree': [1.0], 'eta': [0.30000000000000004], 'gamma': [9.186248496762103], 'max_depth': [28.0], 'min_child_weight': [10.0], 'n_estimators': [3547.0], 'reg_alpha': [19.938811112420893], 'reg_lambda': [10.895703977290431]}
# {'colsample_bytree': [0.9], 'eta': [0.1], 'gamma': [0.5921533104803345], 'max_depth': [22.0], 'min_child_weight': [4.0], 'n_estimators': [3953.0], 'reg_alpha': [15.513788806558086], 'reg_lambda': [4.9700276625402555]}
# {'colsample_bytree': [0.9], 'eta': [0.4], 'gamma': [17.088455776117925], 'max_depth': [18.0], 'min_child_weight': [14.0], 'n_estimators': [5865.0], 'reg_alpha': [10.406450449649425], 'reg_lambda': [1.865301585623496]}
# {'colsample_bytree': [1.0], 'eta': [0.30000000000000004], 'gamma': [8.141891188034915], 'max_depth': [27.0], 'min_child_weight': [10.0], 'n_estimators': [3675.0], 'reg_alpha': [18.201451753767522], 'reg_lambda': [11.49191361249064]}
# {'colsample_bytree': [0.9], 'eta': [0.1], 'gamma': [0.06506621251459332], 'max_depth': [22.0], 'min_child_weight': [8.0], 'n_estimators': [4245.0], 'reg_alpha': [15.554243570910016], 'reg_lambda': [8.018673350750715]}
# {'colsample_bytree': [0.9], 'eta': [0.6000000000000001], 'gamma': [13.63885341992726], 'max_depth': [18.0], 'min_child_weight': [15.0], 'n_estimators': [5980.0], 'reg_alpha': [7.929691024773204], 'reg_lambda': [2.2384516004791934]}
# {'colsample_bytree': [0.8], 'eta': [0.2], 'gamma': [8.017809719284383], 'max_depth': [26.0], 'min_child_weight': [9.0], 'n_estimators': [5230.0], 'reg_alpha': [17.992343759165607], 'reg_lambda': [11.788187849035339]}
# {'colsample_bytree': [0.7000000000000001], 'eta': [1.0], 'gamma': [0.531384771983582], 'max_depth': [23.0], 'min_child_weight': [7.0], 'n_estimators': [4518.0], 'reg_alpha': [14.251170554930583], 'reg_lambda': [8.089849030194516]}
# {'colsample_bytree': [0.5], 'eta': [0.2], 'gamma': [10.385369894016534], 'max_depth': [15.0], 'min_child_weight': [11.0], 'n_estimators': [2862.0], 'reg_alpha': [7.585599072383223], 'reg_lambda': [12.998915083038384]}
# {'colsample_bytree': [0.1], 'eta': [0.7000000000000001], 'gamma': [14.74923341029137], 'max_depth': [14.0], 'min_child_weight': [15.0], 'n_estimators': [4603.0], 'reg_alpha': [9.220358623106968], 'reg_lambda': [9.116456032821816]}
# {'colsample_bytree': [0.1], 'eta': [0.4], 'gamma': [15.37257475002856], 'max_depth': [10.0], 'min_child_weight': [13.0], 'n_estimators': [5235.0], 'reg_alpha': [12.45342976505518], 'reg_lambda': [6.585331210909047]}
# {'colsample_bytree': [0.8], 'eta': [0.7000000000000001], 'gamma': [13.308672294975278], 'max_depth': [30.0], 'min_child_weight': [11.0], 'n_estimators': [1559.0], 'reg_alpha': [19.050325678490207], 'reg_lambda': [19.918518587181744]}
# {'colsample_bytree': [0.6000000000000001], 'eta': [0.5], 'gamma': [11.552796489515837], 'max_depth': [26.0], 'min_child_weight': [12.0], 'n_estimators': [5708.0], 'reg_alpha': [16.73515833864825], 'reg_lambda': [9.046094177531192]}
# {'colsample_bytree': [0.7000000000000001], 'eta': [0.1], 'gamma': [1.565349361135485], 'max_depth': [20.0], 'min_child_weight': [3.0], 'n_estimators': [3100.0], 'reg_alpha': [13.236206174460548], 'reg_lambda': [3.714757826049365]}
# {'colsample_bytree': [0.6000000000000001], 'eta': [0.1], 'gamma': [4.606142410883256], 'max_depth': [23.0], 'min_child_weight': [5.0], 'n_estimators': [2274.0], 'reg_alpha': [11.081986856610522], 'reg_lambda': [6.595401497735338]}
# {'colsample_bytree': [0.2], 'eta': [0.30000000000000004], 'gamma': [18.28663816194137], 'max_depth': [4.0], 'min_child_weight': [19.0], 'n_estimators': [5003.0], 'reg_alpha': [11.98469091768586], 'reg_lambda': [1.5456732807097087]}
# {'colsample_bytree': [0.4], 'eta': [0.6000000000000001], 'gamma': [9.969742422135106], 'max_depth': [3.0], 'min_child_weight': [16.0], 'n_estimators': [4907.0], 'reg_alpha': [9.61615442515381], 'reg_lambda': [3.2579647495622615]}
# {'colsample_bytree': [0.8], 'eta': [0.30000000000000004], 'gamma': [12.65825164805175], 'max_depth': [28.0], 'min_child_weight': [9.0], 'n_estimators': [3204.0], 'reg_alpha': [16.490270852242322], 'reg_lambda': [15.322882060577772]}
# {'colsample_bytree': [1.0], 'eta': [0.2], 'gamma': [9.252840845362268], 'max_depth': [25.0], 'min_child_weight': [7.0], 'n_estimators': [2981.0], 'reg_alpha': [18.255966598745534], 'reg_lambda': [9.914495399964354]}
# {'colsample_bytree': [0.7000000000000001], 'eta': [0.1], 'gamma': [4.472993986106001], 'max_depth': [16.0], 'min_child_weight': [2.0], 'n_estimators': [2555.0], 'reg_alpha': [14.660131234412624], 'reg_lambda': [4.867317814030267]}
# {'colsample_bytree': [0.6000000000000001], 'eta': [0.8], 'gamma': [6.865476480642534], 'max_depth': [20.0], 'min_child_weight': [1.0], 'n_estimators': [1722.0], 'reg_alpha': [14.64855018022006], 'reg_lambda': [4.198519304345567]}
# {'colsample_bytree': [0.0], 'eta': [0.4], 'gamma': [16.54757449011286], 'max_depth': [18.0], 'min_child_weight': [17.0], 'n_estimators': [5510.0], 'reg_alpha': [6.847699119654635], 'reg_lambda': [2.6612395743953354]}
# {'colsample_bytree': [0.2], 'eta': [0.5], 'gamma': [3.6274214702114076], 'max_depth': [8.0], 'min_child_weight': [19.0], 'n_estimators': [5216.0], 'reg_alpha': [11.40450413703061], 'reg_lambda': [7.390581524558569]}

# %%
#Get the best hyperparameters and run the predict again
print(best_hyperparams)
best_hypers = best_hyperparams
# Out:
# {'colsample_bytree': 0.9936978100324734, 'eta': 0.9501439118417301, 'gamma': 1.0, 'max_depth': 17.0, 'min_child_weight': 2.0, 'n_estimators': 2118.0, 'reg_alpha': 8.0, 'reg_lambda': 2.0}

# %%
params = {"objective": "reg:squarederror", 
        "tree_method": "hist",
        "max_depth": int(best_hypers["max_depth"]), 
        "colsample_bytree": best_hypers["colsample_bytree"], 
        "min_child_weight": best_hypers["min_child_weight"], 
        "reg_alpha": best_hypers["reg_alpha"], 
        "reg_lambda": best_hypers["reg_lambda"], 
        "gamma": best_hypers["gamma"], 
        "eta": best_hypers["eta"], 
        #"booster": "dart" #check this for dart https://xgboost.readthedocs.io/en/stable/parameter.html#additional-parameters-for-dart-booster-booster-dart
        }
n = int(best_hypers["n_estimators"])

model = xgb.train(
    params=params,
    dtrain=dtrain_reg,
    num_boost_round=n,
    evals=evals,
    verbose_eval=30, # Every ten rounds
    early_stopping_rounds=50
)

preds = model.predict(dtest_reg)
rmse = mean_squared_error(y_test, preds, squared=False)
print(f"RMSE of the base model: {rmse:.3f}") #the lower the value the better

mape = mean_absolute_percentage_error(y_test, preds)
print(f"MAPE of the base model: {mape:.3f}") #the lower the value the better
# Out:
# [0]	train-rmse:831.42557	validation-rmse:832.62637
# [30]	train-rmse:23.42792	validation-rmse:686.24927
# [51]	train-rmse:16.29540	validation-rmse:686.34204
# RMSE of the base model: 686.347
# MAPE of the base model: 0.087

# %%
model.get_score(importance_type='gain')
# Out:
# {'carat': 25028626.0,
#  'cut': 169468.484375,
#  'color': 1241895.0,
#  'clarity': 2875942.25,
#  'depth': 98386.359375,
#  'table': 37845.75,
#  'x': 85141.015625,
#  'y': 7165253.5,
#  'z': 290613.6875}
